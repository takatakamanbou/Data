# %% [markdown]
# <a href="https://colab.research.google.com/github/takatakamanbou/Data/blob/2025/Data2025_ex11notebookB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data2025 ex11notebookA
#
# <img width=64 src="https://www-tlab.math.ryukoku.ac.jp/~takataka/course/Data/Data-logo11.png"> https://www-tlab.math.ryukoku.ac.jp/wiki/?Data

# %% [markdown]
# ----
# ## 誤差と有効数字の話の演習問題 + $\alpha$
# ----
#
#
#
# <b><font color="#ff0000">
# 注意:
# 今回の notebook の中には，コードセルを実行すると問題の解答が表示されるようになっている箇所があります．
# </font>
# まとめて実行したりせず，読んで理解しながらひとつずつ実行していってください．
# </b>

# %%
# 解答表示のため
import base64
from IPython.display import display, Markdown

# %% [markdown]
# ---
# ### 計算誤差の話の補足

# %% [markdown]
# notebookA の「計算誤差」の項に，次のようなプログラムがありました．
# ```
# # 変数 x を 0 で初期化して，そこに 0.1 を加えることを10回繰り返す
# x = 0
# for i in range(10):
#     x += 0.1
# print(x)
# ```
# このプログラムが正確な値を求められない理由を説明します．
#
# 理由をきちんと理解するためには，コンピュータが小数を2進数でどのように表現するのかについての知識が必要ですが，ここでは簡単のため，まずは10進数で考えましょう．

# %% [markdown]
# <hr width="50%">

# %% [markdown]
# #### 問1
#
# 以下の $\fbox{A}, \fbox{B}, \fbox{C}$ に入る数を答えなさい．
#
# $\frac{1}{3}$ という数を10進数の小数で表すと， $0.\dot{3} = 0.3333\cdots$ という無限小数になる．これを有限桁で，例えば小数点以下3桁までで表そうとすると，下位桁を切り捨てて $\fbox{A}$ とすることになる．
#
# したがって，小数点以下3桁までしか表せない計算機で $\frac{1}{3} + \frac{1}{3} + \frac{1}{3}$ を計算しようとすると，
#
# $$
# \fbox{A} + \fbox{A} + \fbox{A} = \fbox{B}
# $$
#
# となる．この $\fbox{B}$ は，真の値 $\fbox{C}$ と等しくない．

# %%
# このセルを実行すると，上の問題の解答が表示されます
Q = b'CkE6ICQwLjMzMyQsIEI6ICQwLjk5OSQsIEM6ICQxJAo='
display(Markdown(base64.b64decode(Q).decode('utf-8')))

# %% [markdown]
# <hr width="50%">

# %% [markdown]
# 問1で生じた問題と同様のことが，先のプログラムの場合にも起こっています．$0.1$ は10進数では小数第1位までで表せる数ですが，2進数だと
#
# $$
# 0.0\dot{0}01\dot{1}_{(2)} = 0.00011001100110011\cdots _{(2)} \tag{1}
# $$
#
# という循環小数になります．そのため，数を2進数で表すコンピュータでは， $0.1$ を有限の桁数で表せず，誤差が生じてしまう，というわけです．

# %% [markdown]
# ちなみに
#
# $$
# \begin{gathered}
# 0.5 = \frac{1}{2} = 0.1_{(2)}\\
# 0.25 = \frac{1}{4} = 0.01_{(2)}\\
# 0.125 = \frac{1}{8} = 0.001_{(2)}\\
# 0.0625 = \frac{1}{16} = 0.0001_{(2)}\\
# \end{gathered}
# $$
#
# ですので，式(1)の値が $\frac{1}{10}$ に等しいことは，次のように導出されます．
#
# $$
# \begin{aligned}
# &0.0\dot{0}01\dot{1}_{(2)}\\
#  &= 0 \cdot\frac{1}{2} + 0\cdot\frac{1}{4} + 0\cdot\frac{1}{8} + 1\cdot\frac{1}{16} + 1\cdot\frac{1}{32} + 0\cdot\frac{1}{64} + 0\cdot\frac{1}{128} + 1\cdot\frac{1}{256} + 1\cdot\frac{1}{512} + \cdots\\
# &= \frac{1}{16} + \frac{1}{32} + \frac{1}{256} + \frac{1}{512} + \frac{1}{4096} + \frac{1}{8192} + \cdots\\
# &= \left( \frac{1}{16} + \frac{1}{32} \right) + \frac{1}{16}\left( \frac{1}{16} + \frac{1}{32} \right) + \frac{1}{16^2}\left( \frac{1}{16} + \frac{1}{32} \right) + \cdots \\
# &= \frac{3}{32} + \frac{3}{32}\cdot\frac{1}{16} + \frac{3}{32}\cdot\frac{1}{16^2} + \cdots\\
# &= \frac{\frac{3}{32}}{1-\frac{1}{16}} = \frac{1}{10}
# \end{aligned}
# $$

# %% [markdown]
# #### 問2
#
# ここまでの話をふまえて，上記の「# 変数 x を 0 で初期化して，そこに 0.1 を加えることを10回繰り返す」プログラムが正確な値を求められない理由を説明しなさい．

# %% [markdown]
# 解答略

# %% [markdown]
# ---
# ### 演習問題

# %% [markdown]
# #### 問3
#
# 次の3つの数のそれぞれを，有効数字6桁，4桁，2桁で（指数表記/科学的記数法は用いないで）表しなさい．丸めには四捨五入を用いること．
#
# $2357.1113$
#
# $5963808000$
#
# $0.0046492929$

# %%
# このセルを実行すると，上の問題の解答が表示されます
Q = b'CnwgfCB8IHwgfAp8Oi0tfDotLXw6LS18Oi0tfAp8KirmnInlirnmlbDlrZc25qGBKip8JDIzNTcuMTEkfCQ1OTYzODEwMDAwJHwkMC4wMDQ2NDkyOSQKfCoq5pyJ5Yq55pWw5a2XNOahgSoqfCQyMzU3JHwkNTk2NDAwMDAwMCR8JDAuMDA0NjQ5JAp8KirmnInlirnmlbDlrZcy5qGBKip8JDI0MDAkfCQ2MDAwMDAwMDAwJHwkMC4wMDQ2JAo='
display(Markdown(base64.b64decode(Q).decode('utf-8')))

# %% [markdown]
# #### 問4
#
# 問3の3つの数を，科学的記数法を用いて有効数字4桁で表しなさい．丸めには四捨五入を用いること．

# %%
# このセルを実行すると，上の問題の解答が表示されます
Q = b'CiQyLjM1NyBcdGltZXMgMTBeMyxccXVhZCA1Ljk2NCBcdGltZXMgMTBeezl9LFxxdWFkIDQuNjQ5XHRpbWVzIDEwXnstM30kCg=='
display(Markdown(base64.b64decode(Q).decode('utf-8')))

# %% [markdown]
# #### 問5
#
# あるコンピュータプログラムに3つの数値を出力させたところ，次のように表示された．これらの数を大きい順にならべなさい．
#
# ```
# 1.23e+00   -3.45e+02   5.67e-01
# ```

# %%
# このセルを実行すると，上の問題の解答が表示されます
Q = b'CmAxLjIzZSswMCA+IDUuNjdlLTAxID4gLTMuNDVlKzAyYAo='
display(Markdown(base64.b64decode(Q).decode('utf-8')))
